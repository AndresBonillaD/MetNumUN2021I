# %% [markdown]
# #Métodos Numéricos UN 2021 - I
#
# Andres Alejandro Bonilla Duarte
#
# aabonillad@unal.edu.co
#
# Lab 12. Week 5

# %% [markdown]
# https://www.linkedin.com/in/andres-alejandro-bonilla-duarte-04b7b01b6/

# %% [markdown]
# ![in.PNG](data:image/png;base64,...)
